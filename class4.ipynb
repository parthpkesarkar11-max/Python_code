# %%
import random
a=(["Stone","Paper","scissor:"])
user =input(a)
computer = random.choice (a)
print("computer:",computer)
if user==computer:
    print ("It is Tie!")
elif user=="Stone"and computer=="scissor":
    print("You Win")
elif user=="Paper"and computer=="scissor":
    print("You Win")
elif user=="Stone"and computer=="Paper":
    print("You Win")
else:
    print("You Lose")
# Out:
# ['Stone', 'Paper', 'scissor:'] paper
# computer: Stone
# You Lose

# %%
import random
a=random.randint(1,5)
user =input("Enter number")
if user == a:
    print ("You Win")
else :
    print("You lose")
# Out:
# Enter number 2
# You lose

# %%
import random 
a=random.randint(1,5)
while True:
    user= int(input("Enter number"))
    if user==a:
        print("You Win")
        break
    elif user< a:
        print("gvess large value")
    else:
        print("gvess small value")
# Out:
# Enter number 4
# gvess small value
# Enter number 3
# gvess small value
# Enter number 2
# You Win
